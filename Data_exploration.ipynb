# %% [markdown]
# <a href="https://colab.research.google.com/github/AimjGuytidy/WQU-Thesis/blob/main/Data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/oil.csv',index_col=0,parse_dates=True)
# df.set_index('Date',inplace=True)
df.head()
# Out:
#             Price
# Date
# 2017-08-25  47.65
# 2017-08-28  46.40
# 2017-08-29  46.46
# 2017-08-30  45.96
# 2017-08-31  47.26

# %%
px.line(df,y='Price',x=df.index,labels={'x':'Date'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3d01f612-c084-4901-b346-d2fa8f0c9486" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3d01f612-c084-4901-b346-d2fa8f0c9486")) {
#                     Plotly.newPlot(
#                         '3d01f612-c084-4901-b346-d2fa8f0c9486',
# ...

# %%
df.plot(kind='kde',figsize=[14,12]);
